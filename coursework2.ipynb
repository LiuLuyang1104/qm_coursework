# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp

import scipy.stats as sps

# %%
# Load the data into data frames

d1 = pd.read_csv('gcse_results_clear.csv')

# %%
d1.head()
# Out:
#         code                  area 2016_total 2017_total 2018_total  \
# 0  E09000002  Barking_and_Dagenham      2,201      2,185      2,199
# 1  E09000003                Barnet      3,647      3,528      3,810
# 2  E09000004                Bexley      3,192      3,141      3,032
# 3  E09000005                 Brent      3,035      2,908      2,858
# 4  E09000006               Bromley      3,305      3,258      3,214
#
#   2019_total  2016_a8  2017_a8  2018_a8  2019_a8  ...  2018_girl  2019_girl  \
# 0      2,353     49.7     46.7     46.1     46.4  ...      1,080      1,108
# 1      3,804     56.1     54.7     56.0     57.1  ...      1,832      1,818
# 2      3,115     52.2     49.0     49.6     49.6  ...      1,524      1,538
# 3      3,038     51.5     49.0     49.9     50.2  ...      1,378      1,513
# 4      3,312     53.7     49.8     50.3     50.8  ...      1,600      1,713
#
#    2016_a8_g  2017_a8_g 2018_a8_g 2019_a8_g 2016_p8_g 2017_p8_g  2018_p8_g  \
# ...

# %%
print(d1["2018_p8"])
d11=d1["2018_p8"]
# Out:
# 0     0.17
# 1     0.57
# 2    -0.10
# 3     0.54
# 4     0.03
# 5     0.07
# 6     0.07
# 7     0.53
# 8     0.08
# 9    -0.18
# 10    0.31
# 11    0.34
# 12    0.16
# 13    0.45
# 14   -0.09
# 15    0.15
# 16    0.43
# 17    0.15
# 18    0.11
# 19    0.53
# 20   -0.05
# 21   -0.22
# 22    0.44
# 23    0.32
# 24    0.47
# 25    0.14
# 26    0.30
# 27    0.39
# 28    0.15
# 29    0.21
# 30    0.30
# 31    0.47
# Name: 2018_p8, dtype: float64

# %%
plt.style.use('seaborn-white')
x2 = d1["2019_a8_b"]
x3 = d1["2019_a8_g"]
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=10)
plt.hist(x2, **kwargs,label="Boys")
plt.hist(x3, **kwargs,label="Girls",color='r')
plt.xlabel("Average Progress 8 score per pupil",fontsize="large")
plt.ylabel("Number of areas",fontsize="large")
plt.legend()
plt.title('Average scores of different genders in 2019',fontsize='x-large',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Average scores of different genders in 2019')

# %%
plt.style.use('seaborn-white')
x2 = d1["2016_p8_b"]
x3 = d1["2016_p8_g"]
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=12)
plt.hist(x2, **kwargs,label="Boys")
plt.hist(x3, **kwargs,label="Girls",color='r')
plt.xlabel("Average Progress 8 score per pupil",fontsize="large")
plt.ylabel("Number of areas",fontsize="large")
plt.legend()
plt.title('Performance changes of different genders in 2016',fontsize='x-large',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Performance changes of different genders in 2016')

# %%
plt.style.use('seaborn-white')
#最基本的频次直方图命令
x2 = d1["2019_p8_b"]
x3 = d1["2019_p8_g"]
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=12)
plt.hist(x2, **kwargs,label="Boys")
plt.hist(x3, **kwargs,label="Girls",color='r')
plt.xlabel("Average Progress 8 score per pupil",fontsize="large")
plt.ylabel("Number of areas",fontsize="large")
plt.legend()
plt.title('Performance changes of different genders in 2019',fontsize='x-large',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Performance changes of different genders in 2019')

# %%
plt.style.use('seaborn-white')
x2 = d1["2017_p8_b"]
x3 = d1["2017_p8_g"]
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=12)
plt.hist(x2, **kwargs,label="Boys")
plt.hist(x3, **kwargs,label="Girls",color='r')
plt.xlabel("Average Progress 8 score per pupil",fontsize="large")
plt.ylabel("Number of areas",fontsize="large")
plt.legend()
plt.title('Performance changes of different genders in 2017',fontsize='x-large',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Performance changes of different genders in 2017')

# %%
plt.style.use('seaborn-white')
x2 = d1["2016_p8"]
x3 = d1["2017_p8"]

kwargs = dict(histtype='stepfilled', alpha=0.6, bins=8)

plt.hist(x3, **kwargs,label="2016",color="green")

plt.xlabel("Average Progress 8 score per pupil",fontsize="large")
plt.ylabel("Number of areas",fontsize="large")
plt.legend(loc='upper left')
plt.title('Performance changes of students in 2017',fontsize='x-large',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Performance changes of students in 2017')
